# %% [markdown]
# Elabora un programa que permita ingresar el numero partidos ganados, perdidos y empatados del club de futbol "real bañil" en el torneo de apertura 2024, se debe mostrar el puntaje final teniendo en cuenta que por cada partido ganado obtendrá 3 pts, 1pts por los empates y 0 por los perdidos

# %%
print("--------------------------------------------")
print("------------PUNTAJE FINAL-------------------")
print("--------------------------------------------")

#DATOS DE ENTRADA
partidos_ganados = int(input("Ingrese la cantidad de partidos ganados: "))
partidos_perdidos = int(input("Ingrese la cantidad de partidos perdidos: "))
partidos_empatados = int(input("Ingrese la cantidad de partidos empatados: "))

#PROCESO
ganados = partidos_ganados * 3
empatados = partidos_empatados * 1
perdidos = partidos_perdidos * 0

#SALIDA
print("--------------------------------------------")
print("El puntaje final del club es: ", ganados + empatados + perdidos)
print("--------------------------------------------")
# Out:
# --------------------------------------------
# ------------PUNTAJE FINAL-------------------
# --------------------------------------------
# Ingrese la cantidad de partidos ganados: 4
# Ingrese la cantidad de partidos perdidos: 25
# Ingrese la cantidad de partidos empatados: 55
# --------------------------------------------
# El puntaje final del club es:  67
# --------------------------------------------

# %% [markdown]
# Elabora un programa que dado como datos el radio y la altura de un cilindro, calcular e imprimir el area y volumen del mismo

# %%
print("--------------------------------------------")
print("------------AREA Y VOLUMEN DEL CILINDRO-----")
print("--------------------------------------------")

PI=3.1416
radio=float(input("Ingrese el radio del cilindro: "))
altura=float(input("Ingrese la altura del cilindro: "))

#Proceso
area=2*PI*radio*(altura+radio)
volumen=PI*radio**2*altura

#Datos de salida
print("El area del cilindro es : ",area)
print("El volumen del cilindro es: ",volumen)
# Out:
# --------------------------------------------
# ------------AREA Y VOLUMEN DEL CILINDRO-----
# --------------------------------------------
# Ingrese el radio del cilindro: 45
# Ingrese la altura del cilindro: 42
# El area del cilindro es:  24598.728
# El volumen del cilindro es:  267193.08

# %% [markdown]
# Escribe un programa que calcule rl perimetro de un triangulo equilatero, teniendo como dato de entrada la altura

# %%
print("--------------------------------------------")
print("------------PERIMETRO DE UN TRIANGULO------")
print("--------------------------------------------")
#Entrada
altura=float(input("Ingrese la altura del triangulo: "))

#Proceso
import math
lado=altura*2/1.7320508075688772


perimetro=3*lado
#Salida
print("El perimetro del triangulo es: ",perimetro)
# Out:
# --------------------------------------------
# ------------PERIMETRO DE UN TRIANGULO------
# --------------------------------------------
# Ingrese la altura del triangulo: 4
# El perimetro del triangulo es:  13.856406460551021
