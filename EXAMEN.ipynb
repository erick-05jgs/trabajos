# %%
#EXAMEN
#Elaborar un programa que permita calcular el número de discos discos 3.5 necesarios para hacer una copia de seguridad, de la informacíón almacenada en un disco cuya capacidad se conoce.
#Hay que considerar que el disco duro está lleno de información, además expresado en gigabyte. Un micro disco tiene 1.44 megabyte y un gigabyte es igual a 1024 megabyte. (30%)

print("Numero de microdiscos")
#Datos
Micro_discos = 1.44
Disco_duro = 1024

#Proceso
Discos_necesarios=((Disco_duro)/(Micro_discos))
#Salida
print("Microdiscos necesarios",Discos_necesarios)
# Out:
# Numero de microdiscos
# Microdiscos necesarios 711.1111111111111

# %%
#Si se conoce la longitud de dos de los lados de un triangulo (b y c) y el angulo entre ellos (alfa), expresado en grados sexagesimales, la longitud del tercer lado (a) se calcula por la formula: a2 = b2 + c2 - 2bc*Cos(alfa)
print("Medidas b y c")
#Datos
b=int(input("b: "))
c=int(input("c: "))
alfa=int(input("alfa: "))
alfa/360
#Proceso
import math
a2= c*2 - 2*b*c*math.cos(alfa)
a=a2**0.5

#Salida
print("Longitud a",a)
# Out:
# Medidas b y c
# b: 44444444444
# c: 55555
# alfa: 5
# Longitud a (2.2917481691374715e-09+37427087.88743131j)
